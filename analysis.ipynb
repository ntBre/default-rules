# %%
import warnings

warnings.filterwarnings("ignore", message=r".*GIL", category=RuntimeWarning)

# %%
import polars as pl
import subprocess
import json


pl.Config.set_tbl_rows(-1)
pl.Config.set_tbl_cols(-1)
pl.Config.set_fmt_str_lengths(1000);

# %%
RUFF = "./ruff.26230b1ed3"
linter_data = json.loads(
    subprocess.run(
        [RUFF, "linter", "--output-format=json"],
        check=True,
        text=True,
        capture_output=True,
    ).stdout
)
linters = {linter["name"]: linter["prefix"] for linter in linter_data}
rule_data = json.loads(
    subprocess.run(
        [RUFF, "rule", "--all", "--output-format=json"],
        check=True,
        text=True,
        capture_output=True,
    ).stdout
)
rules = {rule["code"]: rule["name"] for rule in rule_data}
rule_to_linter = {rule["code"]: linters[rule["linter"]] for rule in rule_data}

# %%
df = pl.read_csv("out.csv")
full = df.with_columns(
    (
        pl.col("accuracy")
        + 2 * pl.col("severity")
        + 0.5 * pl.col("fixability")
        + pl.col("applicability")
        + pl.col("configuration")
        + pl.col("conflicts")
    ).alias("total"),
    pl.col("rule").replace_strict(rule_to_linter).alias("linter"),
    pl.col("rule").replace_strict(rules).alias("name"),
)

# %%
full.group_by("accuracy").agg(pl.len()).sort("accuracy")
# Out:
# shape: (3, 2)
# ┌──────────┬─────┐
# │ accuracy ┆ len │
# │ ---      ┆ --- │
# │ i64      ┆ u32 │
# ╞══════════╪═════╡
# │ 0        ┆ 76  │
# │ 1        ┆ 60  │
# │ 2        ┆ 802 │
# └──────────┴─────┘

# %%
full.filter(
    pl.col("total") >= 9,
    pl.col("type") == "Stable",
).height
# Out:
# 578

# %%
full.filter(
    pl.col("accuracy") == 2,
    pl.col("total") >= 9,
    pl.col("type") == "Stable",
).height
# Out:
# 551

# %%
# Just requiring a total score >= 9 doesn't really narrow things down enough, even with
# a required accuracy of 2 and limiting to stable rules. Let's impose a few more constraints
# such as no conflicts or redundancy with other tools, a high applicability, and also a high
# severity. This actually requires a total score >= 10 so the >= 9 check is now redundant.
#
# Expanding the applicabilty range to >= 1 just pulls in the pytest rules. pytest was basically
# (maybe literally) the only library I considered widespread enough to warrant a 1.
#
# 197 seems like a pretty reasonable number of default rules (out of 938), just percentage-wise.
df = full.filter(
    pl.col("accuracy") == 2,
    pl.col("type") == "Stable",
    pl.col("conflicts") == 2,
    pl.col("applicability") == 2,
    pl.col("severity") == 2,
)
df.sort("rule")
# Out:
# shape: (197, 11)
# ┌─────────┬────────┬────────┬────────┬────────┬────────┬────────┬────────┬───────┬────────┬────────┐
# │ rule    ┆ type   ┆ accura ┆ severi ┆ fixabi ┆ applic ┆ config ┆ confli ┆ total ┆ linter ┆ name   │
# │ ---     ┆ ---    ┆ cy     ┆ ty     ┆ lity   ┆ abilit ┆ uratio ┆ cts    ┆ ---   ┆ ---    ┆ ---    │
# │ str     ┆ str    ┆ ---    ┆ ---    ┆ ---    ┆ y      ┆ n      ┆ ---    ┆ f64   ┆ str    ┆ str    │
# │         ┆        ┆ i64    ┆ i64    ┆ i64    ┆ ---    ┆ ---    ┆ i64    ┆       ┆        ┆        │
# │         ┆        ┆        ┆        ┆        ┆ i64    ┆ i64    ┆        ┆       ┆        ┆        │
# ╞═════════╪════════╪════════╪════════╪════════╪════════╪════════╪════════╪═══════╪════════╪════════╡
# │ A002    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ A      ┆ builti │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ n-argu │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ment-s │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ hadowi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ng     │
# │ A004    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ A      ┆ builti │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ n-impo │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rt-sha │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ dowing │
# │ A005    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ A      ┆ stdlib │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -modul │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e-shad │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ owing  │
# │ A006    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ A      ┆ builti │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ n-lamb │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ da-arg │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ument- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ shadow │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ing    │
# │ ARG001  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ ARG    ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -funct │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ion-ar │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ gument │
# │ ARG002  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ ARG    ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -metho │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-argu │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ment   │
# │ ARG003  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ ARG    ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -class │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -metho │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-argu │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ment   │
# │ ARG004  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ ARG    ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -stati │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ c-meth │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ od-arg │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ument  │
# │ ARG005  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ ARG    ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -lambd │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ a-argu │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ment   │
# │ ASYNC10 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ cancel │
# │ 0       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -scope │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -no-ch │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ eckpoi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nt     │
# │ ASYNC22 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ create │
# │ 0       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -subpr │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ocess- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ in-asy │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nc-fun │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ction  │
# │ ASYNC22 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ run-pr │
# │ 1       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ocess- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ in-asy │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nc-fun │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ction  │
# │ ASYNC22 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ wait-f │
# │ 2       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ or-pro │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cess-i │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ n-asyn │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ c-func │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ tion   │
# │ ASYNC25 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ blocki │
# │ 1       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ng-sle │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ep-in- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ async- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ functi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ on     │
# │ B002    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ unary- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ prefix │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -incre │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ment-d │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ecreme │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nt     │
# │ B003    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ assign │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ment-t │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ o-os-e │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nviron │
# │ B004    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ B      ┆ unreli │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ able-c │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ allabl │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e-chec │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ k      │
# │ B005    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ strip- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ with-m │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ulti-c │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ haract │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ers    │
# │ B012    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ jump-s │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ tateme │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nt-in- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ finall │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ y      │
# │ B015    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ useles │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ s-comp │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ arison │
# │ B016    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ raise- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ litera │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ l      │
# │ B017    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ assert │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -raise │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ s-exce │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ption  │
# │ B019    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ cached │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -insta │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nce-me │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ thod   │
# │ B020    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ loop-v │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ariabl │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e-over │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rides- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ iterat │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ or     │
# │ B021    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ f-stri │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ng-doc │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ string │
# │ B022    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ useles │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ s-cont │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ extlib │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -suppr │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ess    │
# │ B025    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ duplic │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ate-tr │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ y-bloc │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ k-exce │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ption  │
# │ B029    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ except │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -with- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ empty- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ tuple  │
# │ B030    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ except │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -with- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ non-ex │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ceptio │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ n-clas │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ses    │
# │ B031    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ reuse- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ of-gro │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ upby-g │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ enerat │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ or     │
# │ B032    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ uninte │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ntiona │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ l-type │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -annot │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ation  │
# │ B035    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ B      ┆ static │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -key-d │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ict-co │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ mprehe │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nsion  │
# │ E722    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆        ┆ bare-e │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ xcept  │
# │ E902    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆        ┆ io-err │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ or     │
# │ EXE001  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ EXE    ┆ sheban │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-not- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ execut │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ able   │
# │ EXE002  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ EXE    ┆ sheban │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-miss │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ing-ex │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ecutab │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ le-fil │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e      │
# │ EXE003  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ EXE    ┆ sheban │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-miss │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ing-py │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ thon   │
# │ EXE004  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ EXE    ┆ sheban │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-lead │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ing-wh │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ itespa │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ce     │
# │ EXE005  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ EXE    ┆ sheban │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-not- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ first- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ line   │
# │ F401    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 1      ┆ 2      ┆ 12.0  ┆ F      ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -impor │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t      │
# │ F402    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ import │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -shado │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ wed-by │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -loop- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ var    │
# │ F403    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ undefi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ned-lo │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cal-wi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ th-imp │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ort-st │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ar     │
# │ F404    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ late-f │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ uture- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ import │
# │ F405    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ undefi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ned-lo │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cal-wi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ th-imp │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ort-st │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ar-usa │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ge     │
# │ F406    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ undefi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ned-lo │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cal-wi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ th-nes │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ted-im │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ port-s │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ tar-us │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ age    │
# │ F407    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ future │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -featu │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ re-not │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -defin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ed     │
# │ F501    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ percen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at-inv │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ alid-f │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ormat  │
# │ F502    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ percen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at-exp │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ected- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ mappin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g      │
# │ F503    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ percen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at-exp │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ected- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ sequen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ce     │
# │ F504    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ F      ┆ percen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at-ext │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ra-nam │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ed-arg │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ uments │
# │ F505    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ percen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at-mis │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ sing-a │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rgumen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t      │
# │ F506    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ percen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at-mix │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ed-pos │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ itiona │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ l-and- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ named  │
# │ F507    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ percen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at-pos │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ itiona │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ l-coun │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-mism │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ atch   │
# │ F508    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ percen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at-sta │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ r-requ │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ires-s │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ equenc │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e      │
# │ F509    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ percen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at-uns │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ upport │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ed-for │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ mat-ch │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ aracte │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ r      │
# │ F521    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ string │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -dot-f │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ormat- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ at     │
# │ F522    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ F      ┆ string │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -dot-f │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ormat- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ extra- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ named- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ argume │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nts    │
# │ F523    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ F      ┆ string │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -dot-f │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ormat- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ extra- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ positi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ onal-a │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rgumen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ts     │
# │ F524    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ string │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -dot-f │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ormat- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ missin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-argu │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ments  │
# │ F525    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ string │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -dot-f │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ormat- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ mixing │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -autom │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ atic   │
# │ F601    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ F      ┆ multi- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ value- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ repeat │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ed-key │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -liter │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ al     │
# │ F602    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ F      ┆ multi- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ value- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ repeat │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ed-key │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -varia │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ble    │
# │ F621    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ expres │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ sions- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ in-sta │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ r-assi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ gnment │
# │ F622    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ multip │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ le-sta │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rred-e │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ xpress │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ions   │
# │ F631    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ assert │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -tuple │
# │ F632    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ F      ┆ is-lit │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ eral   │
# │ F633    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-prin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-synt │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ax     │
# │ F634    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ if-tup │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ le     │
# │ F701    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ break- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ outsid │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e-loop │
# │ F702    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ contin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ue-out │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ side-l │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ oop    │
# │ F704    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ yield- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ outsid │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e-func │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ tion   │
# │ F706    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ return │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -outsi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ de-fun │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ction  │
# │ F707    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ defaul │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-exce │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ pt-not │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -last  │
# │ F811    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 1      ┆ 2      ┆ 12.0  ┆ F      ┆ redefi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ned-wh │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ile-un │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ used   │
# │ F821    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ F      ┆ undefi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ned-na │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ me     │
# │ F822    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ undefi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ned-ex │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ port   │
# │ F823    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ F      ┆ undefi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ned-lo │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cal    │
# │ F841    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 1      ┆ 2      ┆ 12.0  ┆ F      ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -varia │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ble    │
# │ F842    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ F      ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -annot │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ation  │
# │ FURB163 ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ FURB   ┆ redund │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ant-lo │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-base │
# │ INT001  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ INT    ┆ f-stri │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ng-in- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ get-te │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ xt-fun │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ c-call │
# │ INT002  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ INT    ┆ format │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -in-ge │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-text │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -func- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ call   │
# │ INT003  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 1      ┆ 2      ┆ 11.0  ┆ INT    ┆ printf │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -in-ge │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-text │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -func- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ call   │
# │ LOG001  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ LOG    ┆ direct │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -logge │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ r-inst │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ antiat │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ion    │
# │ PIE794  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ PIE    ┆ duplic │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ate-cl │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ass-fi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ eld-de │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ finiti │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ on     │
# │ PIE796  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PIE    ┆ non-un │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ique-e │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nums   │
# │ PLC0131 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ type-b │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ivaria │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nce    │
# │ PLC0132 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ type-p │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ aram-n │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ame-mi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ smatch │
# │ PLC0205 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ single │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -strin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-slot │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ s      │
# │ PLE0100 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ yield- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ in-ini │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t      │
# │ PLE0101 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ return │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -in-in │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ it     │
# │ PLE0115 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ nonloc │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ al-and │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -globa │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ l      │
# │ PLE0116 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ contin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ue-in- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ finall │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ y      │
# │ PLE0117 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ nonloc │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ al-wit │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ hout-b │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ inding │
# │ PLE0118 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ load-b │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ efore- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ global │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -decla │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ration │
# │ PLE0241 ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ PL     ┆ duplic │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ate-ba │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ses    │
# │ PLE0302 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ unexpe │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cted-s │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ pecial │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -metho │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-sign │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ature  │
# │ PLE0303 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-leng │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ th-ret │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ urn-ty │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ pe     │
# │ PLE0305 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-inde │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ x-retu │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rn-typ │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e      │
# │ PLE0307 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-str- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ return │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -type  │
# │ PLE0308 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ PL     ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-byte │
# ...
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ter-co │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ mment  │
# │ RUF016  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ RUF    ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-inde │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ x-type │
# │ RUF018  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ RUF    ┆ assign │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ment-i │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ n-asse │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rt     │
# │ RUF026  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ RUF    ┆ defaul │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-fact │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ory-kw │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ arg    │
# │ RUF028  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ RUF    ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-form │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ atter- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ suppre │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ssion- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ commen │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t      │
# │ RUF030  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ RUF    ┆ assert │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -with- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ print- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ messag │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e      │
# │ RUF033  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ RUF    ┆ post-i │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nit-de │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ fault  │
# │ RUF034  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ RUF    ┆ useles │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ s-if-e │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ lse    │
# │ RUF040  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ RUF    ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-asse │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rt-mes │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ sage-l │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ iteral │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -argum │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ent    │
# │ RUF048  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ RUF    ┆ map-in │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-vers │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ion-pa │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsing  │
# │ RUF049  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ RUF    ┆ datacl │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ass-en │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ um     │
# │ RUF053  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ RUF    ┆ class- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ with-m │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ixed-t │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ype-va │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rs     │
# │ RUF059  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 1      ┆ 2      ┆ 12.0  ┆ RUF    ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -unpac │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ked-va │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ riable │
# │ RUF100  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 1      ┆ 2      ┆ 12.0  ┆ RUF    ┆ unused │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -noqa  │
# │ RUF101  ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ RUF    ┆ redire │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cted-n │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ oqa    │
# │ RUF200  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ RUF    ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-pypr │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ oject- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ toml   │
# │ SIM107  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ SIM    ┆ return │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -in-tr │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ y-exce │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ pt-fin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ally   │
# │ T100    ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ T10    ┆ debugg │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ er     │
# │ TC004   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 1      ┆ 2      ┆ 12.0  ┆ TC     ┆ runtim │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e-impo │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rt-in- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ type-c │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ heckin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-bloc │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ k      │
# │ TC007   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ TC     ┆ unquot │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ed-typ │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e-alia │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ s      │
# │ TC010   ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ TC     ┆ runtim │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e-stri │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ng-uni │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ on     │
# │ TRY300  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ TRY    ┆ try-co │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nsider │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -else  │
# │ UP005   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ UP     ┆ deprec │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ated-u │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nittes │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-alia │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ s      │
# │ UP019   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ UP     ┆ typing │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -text- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ str-al │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ias    │
# │ UP021   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ UP     ┆ replac │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e-univ │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ersal- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ newlin │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ es     │
# │ UP023   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ UP     ┆ deprec │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ated-c │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -eleme │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nt-tre │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e      │
# │ UP024   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ UP     ┆ os-err │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ or-ali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ as     │
# │ UP035   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ UP     ┆ deprec │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ated-i │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ mport  │
# │ UP036   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 11.0  ┆ UP     ┆ outdat │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ed-ver │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ sion-b │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ lock   │
# │ UP041   ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 1      ┆ 2      ┆ 12.0  ┆ UP     ┆ timeou │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t-erro │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ r-alia │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ s      │
# │ W605    ┆ Stable ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆        ┆ invali │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ d-esca │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ pe-seq │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ uence  │
# │ YTT101  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ YTT    ┆ sys-ve │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsion- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ slice3 │
# │ YTT102  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ YTT    ┆ sys-ve │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsion2 │
# │ YTT103  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ YTT    ┆ sys-ve │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsion- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cmp-st │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ r3     │
# │ YTT201  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ YTT    ┆ sys-ve │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsion- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ info0- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ eq3    │
# │ YTT203  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ YTT    ┆ sys-ve │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsion- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ info1- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cmp-in │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ t      │
# │ YTT204  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ YTT    ┆ sys-ve │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsion- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ info-m │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ inor-c │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ mp-int │
# │ YTT301  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ YTT    ┆ sys-ve │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsion0 │
# │ YTT302  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ YTT    ┆ sys-ve │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsion- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cmp-st │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ r10    │
# │ YTT303  ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ YTT    ┆ sys-ve │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ rsion- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ slice1 │
# └─────────┴────────┴────────┴────────┴────────┴────────┴────────┴────────┴───────┴────────┴────────┘

# %%
# fmt: off
current_defaults = [
    "E401",	    "E742",	    "F504",	    "F602",	    "F811",
    "E712",	    "F404",	    "F521",	    "F634",	    "F901",
    "E741",	    "F503",	    "F601",	    "F722",	    "E711",
    "F403",	    "F509",	    "F633",	    "F842",	    "E731",
    "F502",	    "F541",	    "F707",	    "E703",	    "F402",
    "F508",	    "F632",	    "F841",	    "E722",	    "F501",
    "F525",	    "F706",	    "E702",	    "F401",	    "F507",
    "F631",	    "F823",	    "E721",	    "F407",	    "F524",
    "F704",	    "E701",	    "E902",	    "F506",	    "F622",
    "F822",	    "E714",	    "F406",	    "F523",	    "F702",
    "E402",	    "E743",	    "F505",	    "F621",	    "F821",
    "E713",	    "F405",	    "F522",	    "F701",
]
# fmt: on
len(current_defaults)
# Out:
# 59

# %%
in_defaults = pl.col("rule").is_in(current_defaults)
len(df.filter(in_defaults))
# Out:
# 42

# %%
missing_current_defaults = set(current_defaults) - set(df["rule"])
len(missing_current_defaults)
# Out:
# 17

# %%
# looks like these all got filtered out for severity == 1
full.filter(pl.col("rule").is_in(missing_current_defaults)).sort("rule")
# Out:
# shape: (17, 11)
# ┌──────┬────────┬─────────┬─────────┬─────────┬────────┬────────┬────────┬───────┬────────┬────────┐
# │ rule ┆ type   ┆ accurac ┆ severit ┆ fixabil ┆ applic ┆ config ┆ confli ┆ total ┆ linter ┆ name   │
# │ ---  ┆ ---    ┆ y       ┆ y       ┆ ity     ┆ abilit ┆ uratio ┆ cts    ┆ ---   ┆ ---    ┆ ---    │
# │ str  ┆ str    ┆ ---     ┆ ---     ┆ ---     ┆ y      ┆ n      ┆ ---    ┆ f64   ┆ str    ┆ str    │
# │      ┆        ┆ i64     ┆ i64     ┆ i64     ┆ ---    ┆ ---    ┆ i64    ┆       ┆        ┆        │
# │      ┆        ┆         ┆         ┆         ┆ i64    ┆ i64    ┆        ┆       ┆        ┆        │
# ╞══════╪════════╪═════════╪═════════╪═════════╪════════╪════════╪════════╪═══════╪════════╪════════╡
# │ E401 ┆ Stable ┆ 2       ┆ 1       ┆ 2       ┆ 2      ┆ 2      ┆ 2      ┆ 11.0  ┆        ┆ multip │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ le-imp │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ orts-o │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ n-one- │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ line   │
# │ E402 ┆ Stable ┆ 2       ┆ 1       ┆ 0       ┆ 2      ┆ 2      ┆ 2      ┆ 10.0  ┆        ┆ module │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ -impor │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ t-not- │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ at-top │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ -of-fi │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ le     │
# │ E701 ┆ Stable ┆ 2       ┆ 1       ┆ 0       ┆ 2      ┆ 2      ┆ 1      ┆ 9.0   ┆        ┆ multip │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ le-sta │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ tement │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ s-on-o │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ne-lin │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ e-colo │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ n      │
# │ E702 ┆ Stable ┆ 2       ┆ 1       ┆ 0       ┆ 2      ┆ 2      ┆ 1      ┆ 9.0   ┆        ┆ multip │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ le-sta │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ tement │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ s-on-o │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ne-lin │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ e-semi │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ colon  │
# │ E703 ┆ Stable ┆ 2       ┆ 1       ┆ 2       ┆ 2      ┆ 2      ┆ 1      ┆ 10.0  ┆        ┆ useles │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ s-semi │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ colon  │
# │ E711 ┆ Stable ┆ 2       ┆ 1       ┆ 2       ┆ 2      ┆ 2      ┆ 2      ┆ 11.0  ┆        ┆ none-c │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ompari │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ son    │
# │ E712 ┆ Stable ┆ 2       ┆ 1       ┆ 2       ┆ 2      ┆ 2      ┆ 2      ┆ 11.0  ┆        ┆ true-f │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ alse-c │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ompari │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ son    │
# │ E713 ┆ Stable ┆ 2       ┆ 1       ┆ 2       ┆ 2      ┆ 2      ┆ 2      ┆ 11.0  ┆        ┆ not-in │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ -test  │
# │ E714 ┆ Stable ┆ 2       ┆ 1       ┆ 2       ┆ 2      ┆ 2      ┆ 2      ┆ 11.0  ┆        ┆ not-is │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ -test  │
# │ E721 ┆ Stable ┆ 2       ┆ 1       ┆ 0       ┆ 2      ┆ 2      ┆ 2      ┆ 10.0  ┆        ┆ type-c │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ompari │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ son    │
# │ E731 ┆ Stable ┆ 2       ┆ 1       ┆ 1       ┆ 2      ┆ 2      ┆ 2      ┆ 10.5  ┆        ┆ lambda │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ -assig │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ nment  │
# │ E741 ┆ Stable ┆ 2       ┆ 1       ┆ 0       ┆ 2      ┆ 2      ┆ 2      ┆ 10.0  ┆        ┆ ambigu │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ous-va │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ riable │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ -name  │
# │ E742 ┆ Stable ┆ 2       ┆ 1       ┆ 0       ┆ 2      ┆ 2      ┆ 2      ┆ 10.0  ┆        ┆ ambigu │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ous-cl │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ass-na │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ me     │
# │ E743 ┆ Stable ┆ 2       ┆ 1       ┆ 0       ┆ 2      ┆ 2      ┆ 2      ┆ 10.0  ┆        ┆ ambigu │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ous-fu │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ nction │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ -name  │
# │ F541 ┆ Stable ┆ 2       ┆ 1       ┆ 2       ┆ 2      ┆ 2      ┆ 2      ┆ 11.0  ┆ F      ┆ f-stri │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ng-mis │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ sing-p │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ laceho │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ lders  │
# │ F722 ┆ Stable ┆ 2       ┆ 1       ┆ 0       ┆ 2      ┆ 2      ┆ 2      ┆ 10.0  ┆ F      ┆ forwar │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ d-anno │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ tation │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ -synta │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ x-erro │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ r      │
# │ F901 ┆ Stable ┆ 2       ┆ 1       ┆ 2       ┆ 2      ┆ 2      ┆ 2      ┆ 11.0  ┆ F      ┆ raise- │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ not-im │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ plemen │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ted    │
# └──────┴────────┴─────────┴─────────┴─────────┴────────┴────────┴────────┴───────┴────────┴────────┘

# %%
# looks like these were filtered out for accuracy = 1, I think I was
# probably too harsh here. There's an open bug report from dscorbett
# with a false negative, which is the only reason I can identify for this
full.filter(pl.col("rule").is_in(("A001", "A003")))
# Out:
# shape: (2, 11)
# ┌──────┬────────┬─────────┬─────────┬─────────┬────────┬────────┬────────┬───────┬────────┬────────┐
# │ rule ┆ type   ┆ accurac ┆ severit ┆ fixabil ┆ applic ┆ config ┆ confli ┆ total ┆ linter ┆ name   │
# │ ---  ┆ ---    ┆ y       ┆ y       ┆ ity     ┆ abilit ┆ uratio ┆ cts    ┆ ---   ┆ ---    ┆ ---    │
# │ str  ┆ str    ┆ ---     ┆ ---     ┆ ---     ┆ y      ┆ n      ┆ ---    ┆ f64   ┆ str    ┆ str    │
# │      ┆        ┆ i64     ┆ i64     ┆ i64     ┆ ---    ┆ ---    ┆ i64    ┆       ┆        ┆        │
# │      ┆        ┆         ┆         ┆         ┆ i64    ┆ i64    ┆        ┆       ┆        ┆        │
# ╞══════╪════════╪═════════╪═════════╪═════════╪════════╪════════╪════════╪═══════╪════════╪════════╡
# │ A001 ┆ Stable ┆ 1       ┆ 2       ┆ 0       ┆ 2      ┆ 1      ┆ 2      ┆ 10.0  ┆ A      ┆ builti │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ n-vari │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ able-s │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ hadowi │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ng     │
# │ A003 ┆ Stable ┆ 1       ┆ 2       ┆ 0       ┆ 2      ┆ 1      ┆ 2      ┆ 10.0  ┆ A      ┆ builti │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ n-attr │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ibute- │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ shadow │
# │      ┆        ┆         ┆         ┆         ┆        ┆        ┆        ┆       ┆        ┆ ing    │
# └──────┴────────┴─────────┴─────────┴─────────┴────────┴────────┴────────┴───────┴────────┴────────┘

# %%
# the ASYNC rules feel kind of out of place to me as defaults,
# not all projects are going to write any async code. I think
# we could consider revising the Applicability rubric to something like:
# - 2) widely used stdlib types
# - 1) "Niche" stdlib types or very widely used third-party
# - 0) Niche third-party
df.filter(pl.col("linter") == "ASYNC")
# Out:
# shape: (5, 11)
# ┌─────────┬────────┬────────┬────────┬────────┬────────┬────────┬────────┬───────┬────────┬────────┐
# │ rule    ┆ type   ┆ accura ┆ severi ┆ fixabi ┆ applic ┆ config ┆ confli ┆ total ┆ linter ┆ name   │
# │ ---     ┆ ---    ┆ cy     ┆ ty     ┆ lity   ┆ abilit ┆ uratio ┆ cts    ┆ ---   ┆ ---    ┆ ---    │
# │ str     ┆ str    ┆ ---    ┆ ---    ┆ ---    ┆ y      ┆ n      ┆ ---    ┆ f64   ┆ str    ┆ str    │
# │         ┆        ┆ i64    ┆ i64    ┆ i64    ┆ ---    ┆ ---    ┆ i64    ┆       ┆        ┆        │
# │         ┆        ┆        ┆        ┆        ┆ i64    ┆ i64    ┆        ┆       ┆        ┆        │
# ╞═════════╪════════╪════════╪════════╪════════╪════════╪════════╪════════╪═══════╪════════╪════════╡
# │ ASYNC10 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ cancel │
# │ 0       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -scope │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -no-ch │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ eckpoi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nt     │
# │ ASYNC22 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ create │
# │ 0       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ -subpr │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ocess- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ in-asy │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nc-fun │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ction  │
# │ ASYNC22 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ run-pr │
# │ 1       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ocess- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ in-asy │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ nc-fun │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ction  │
# │ ASYNC22 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ wait-f │
# │ 2       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ or-pro │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ cess-i │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ n-asyn │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ c-func │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ tion   │
# │ ASYNC25 ┆ Stable ┆ 2      ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ ASYNC  ┆ blocki │
# │ 1       ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ng-sle │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ep-in- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ async- │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ functi │
# │         ┆        ┆        ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ on     │
# └─────────┴────────┴────────┴────────┴────────┴────────┴────────┴────────┴───────┴────────┴────────┘

# %%
# Similarly, the EXE rules probably shouldn't be default
# because they don't even do anything on Windows, and many
# projects may not have any executable Python scripts.
df.filter(pl.col("linter") == "EXE")
# Out:
# shape: (5, 11)
# ┌────────┬────────┬─────────┬────────┬────────┬────────┬────────┬────────┬───────┬────────┬────────┐
# │ rule   ┆ type   ┆ accurac ┆ severi ┆ fixabi ┆ applic ┆ config ┆ confli ┆ total ┆ linter ┆ name   │
# │ ---    ┆ ---    ┆ y       ┆ ty     ┆ lity   ┆ abilit ┆ uratio ┆ cts    ┆ ---   ┆ ---    ┆ ---    │
# │ str    ┆ str    ┆ ---     ┆ ---    ┆ ---    ┆ y      ┆ n      ┆ ---    ┆ f64   ┆ str    ┆ str    │
# │        ┆        ┆ i64     ┆ i64    ┆ i64    ┆ ---    ┆ ---    ┆ i64    ┆       ┆        ┆        │
# │        ┆        ┆         ┆        ┆        ┆ i64    ┆ i64    ┆        ┆       ┆        ┆        │
# ╞════════╪════════╪═════════╪════════╪════════╪════════╪════════╪════════╪═══════╪════════╪════════╡
# │ EXE001 ┆ Stable ┆ 2       ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ EXE    ┆ sheban │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-not- │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ execut │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ able   │
# │ EXE002 ┆ Stable ┆ 2       ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ EXE    ┆ sheban │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-miss │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ing-ex │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ecutab │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ le-fil │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ e      │
# │ EXE003 ┆ Stable ┆ 2       ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ EXE    ┆ sheban │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-miss │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ing-py │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ thon   │
# │ EXE004 ┆ Stable ┆ 2       ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 2      ┆ 13.0  ┆ EXE    ┆ sheban │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-lead │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ing-wh │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ itespa │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ ce     │
# │ EXE005 ┆ Stable ┆ 2       ┆ 2      ┆ 0      ┆ 2      ┆ 2      ┆ 2      ┆ 12.0  ┆ EXE    ┆ sheban │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ g-not- │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ first- │
# │        ┆        ┆         ┆        ┆        ┆        ┆        ┆        ┆       ┆        ┆ line   │
# └────────┴────────┴─────────┴────────┴────────┴────────┴────────┴────────┴───────┴────────┴────────┘
